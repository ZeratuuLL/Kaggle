# %%
import pandas as pd
import numpy as np

# %%
logit = pd.read_pickle('LR_tune.pkl')
logit.sort_values(by = ['offline_score_rounded'], ascending=False)[:10]
# Out:
#         C  accuracy  neg_log_loss  offline_score  offline_score_rounded
# 4    1.00  0.461167     -1.236802       0.685887               0.686799
# 3    0.50  0.460333     -1.236778       0.685882               0.686798
# 6   10.00  0.461333     -1.236825       0.685891               0.686788
# 5    5.00  0.461167     -1.236822       0.685891               0.686784
# 7   50.00  0.461333     -1.236827       0.685892               0.686784
# 8  100.00  0.461333     -1.236827       0.685892               0.686784
# 2    0.10  0.460167     -1.236618       0.685842               0.686714
# 1    0.05  0.460167     -1.236490       0.685791               0.686704
# 0    0.01  0.454333     -1.237043       0.685393               0.686405

# %%
RF = pd.read_pickle('RF_tune.pkl')
RF.sort_values(by = ['offline_score_rounded'], ascending=False)#[:10]
# Out:
#     n_estimators  max_depth  accuracy  neg_log_loss  offline_score  \
# 3          250.0        6.0  0.509833     -1.126403       0.694305
# 6          500.0        6.0  0.511500     -1.125574       0.694401
# 9         1000.0        6.0  0.512833     -1.126133       0.694326
# 10        1000.0        8.0  0.511667     -1.128433       0.694043
# 0          100.0        6.0  0.512167     -1.128362       0.694010
# 7          500.0        8.0  0.510000     -1.129331       0.693976
# 4          250.0        8.0  0.510333     -1.130670       0.693648
# 1          100.0        8.0  0.510333     -1.133782       0.693592
# 5          250.0       10.0  0.496333     -1.167982       0.690498
# 11        1000.0       10.0  0.497667     -1.167147       0.690518
# 2          100.0       10.0  0.495167     -1.169909       0.690531
# 8          500.0       10.0  0.499167     -1.167662       0.690407
#
#     offline_score_rounded
# 3                0.695359
# 6                0.695301
# ...

# %%
XGB = pd.read_pickle('XGB_tune.pkl')
XGB.sort_values(by = ['offline_score_rounded'], ascending=False)#[:10]
# Out:
#     n_estimators  learning_rate  max_depth  accuracy  neg_log_loss  \
# 24         500.0           0.01        6.0  0.500167     -1.143586
# 3          100.0           0.05        6.0  0.502667     -1.143103
# 33        1000.0           0.01        6.0  0.494000     -1.168952
# 0          100.0           0.10        6.0  0.497667     -1.168625
# 12         250.0           0.05        6.0  0.491000     -1.181755
# 4          100.0           0.05        8.0  0.485500     -1.188643
# 25         500.0           0.01        8.0  0.486667     -1.187039
# 9          250.0           0.10        6.0  0.481667     -1.234077
# 21         500.0           0.05        6.0  0.484000     -1.234353
# 34        1000.0           0.01        8.0  0.480667     -1.232914
# 1          100.0           0.10        8.0  0.481000     -1.233287
# 13         250.0           0.05        8.0  0.475000     -1.251171
# 26         500.0           0.01       10.0  0.479333     -1.232814
# ...

# %%
CatBoost = pd.read_pickle('catboost_tune.pkl')
CatBoost.sort_values(by = ['offline_score_rounded'], ascending=False)#[:10]
# Out:
#     iterations  learning_rate  max_depth  accuracy  neg_log_loss  \
# 33      1000.0           0.01        6.0  0.519500     -1.113338
# 1        100.0           0.10        8.0  0.518167     -1.114003
# 34      1000.0           0.01        8.0  0.514833     -1.114137
# 0        100.0           0.10        6.0  0.515500     -1.113829
# 13       250.0           0.05        8.0  0.517333     -1.115683
# 12       250.0           0.05        6.0  0.516500     -1.114152
# 9        250.0           0.10        6.0  0.512167     -1.117428
# 35      1000.0           0.01       10.0  0.517000     -1.118162
# 24       500.0           0.01        6.0  0.520667     -1.120202
# 25       500.0           0.01        8.0  0.518667     -1.117815
# 21       500.0           0.05        6.0  0.512833     -1.118496
# 3        100.0           0.05        6.0  0.520000     -1.120393
# 4        100.0           0.05        8.0  0.519667     -1.118168
# ...

# %%
light = pd.read_pickle('lightgbm_tune.pkl')
light.sort_values(by = ['offline_score_rounded'], ascending=False)
# Out:
#     n_estimators  learning_rate  max_depth  accuracy  neg_log_loss  \
# 15         250.0           0.01        6.0  0.498667     -1.135254
# 3          100.0           0.05        6.0  0.499167     -1.134964
# 24         500.0           0.01        6.0  0.498833     -1.135988
# 16         250.0           0.01        8.0  0.504167     -1.137802
# 17         250.0           0.01       10.0  0.503833     -1.139072
# 4          100.0           0.05        8.0  0.499167     -1.142322
# 25         500.0           0.01        8.0  0.502333     -1.142843
# 26         500.0           0.01       10.0  0.500500     -1.145484
# 5          100.0           0.05       10.0  0.502167     -1.146529
# 33        1000.0           0.01        6.0  0.500500     -1.157070
# 1          100.0           0.10        8.0  0.495833     -1.171522
# 0          100.0           0.10        6.0  0.498500     -1.158806
# 12         250.0           0.05        6.0  0.500167     -1.166916
# ...
