# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import os.path

# %% [markdown]
# Put all data files into a folder names 'data'. Then put the folder and this .ipynb file in the same folder. The following block should be able to read in the files for you. Now it only reads in the first

# %%
files = os.listdir('./data/')
DataFrames = {}
for file in files:
    DataFrames[file] = pd.read_csv('./data/' + file, nrows=100, dtype = {'fullVisitorID':str})

# %%
files
# Out:
# ['test.csv', 'train.csv']

# %%
DataFrames[files[0]].head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1  Organic Search  20171016
# 2  Organic Search  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  6167871330617112363
# 1  {"browser": "Chrome", "browserVersion": "not a...   643697640977915618
# 2  {"browser": "Chrome", "browserVersion": "not a...  6059383810968229466
# 3  {"browser": "Safari", "browserVersion": "not a...  2376720078563423631
# 4  {"browser": "Safari", "browserVersion": "not a...  2314544520795440038
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Southea...
# 1  {"continent": "Europe", "subContinent": "South...
# 2  {"continent": "Europe", "subContinent": "Weste...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  6167871330617112363_1508151024  Not Socially Engaged
# 1  0643697640977915618_1508175522  Not Socially Engaged
# 2  6059383810968229466_1508143220  Not Socially Engaged
# 3  2376720078563423631_1508193530  Not Socially Engaged
# 4  2314544520795440038_1508217442  Not Socially Engaged
#
#                                               totals  \
# 0     {"visits": "1", "hits": "4", "pageviews": "4"}
# 1  {"visits": "1", "hits": "5", "pageviews": "5",...
# 2  {"visits": "1", "hits": "7", "pageviews": "7",...
# 3  {"visits": "1", "hits": "8", "pageviews": "4",...
# 4  {"visits": "1", "hits": "9", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508151024            2
# 1  {"campaign": "(not set)", "source": "google", ...  1508175522            1
# 2  {"campaign": "(not set)", "source": "google", ...  1508143220            1
# 3  {"campaign": "(not set)", "source": "google", ...  1508193530            1
# 4  {"campaign": "(not set)", "source": "google", ...  1508217442            1
#
#    visitStartTime
# 0      1508151024
# 1      1508175522
# 2      1508143220
# 3      1508193530
# 4      1508217442

# %%
DataFrames[files[0]].columns
# Out:
# Index(['channelGrouping', 'date', 'device', 'fullVisitorId', 'geoNetwork',
#        'sessionId', 'socialEngagementType', 'totals', 'trafficSource',
#        'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %%
DataFrames[files[1]].head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
#                         sessionId  socialEngagementType  \
# 0  1131660440785968503_1472830385  Not Socially Engaged
# 1   377306020877927890_1472880147  Not Socially Engaged
# 2  3895546263509774583_1472865386  Not Socially Engaged
# 3  4763447161404445595_1472881213  Not Socially Engaged
# 4    27294437909732085_1472822600  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "1", "pageviews": "1",...
# 2  {"visits": "1", "hits": "1", "pageviews": "1",...
# 3  {"visits": "1", "hits": "1", "pageviews": "1",...
# 4  {"visits": "1", "hits": "1", "pageviews": "1",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1472830385            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472880147            1
# 2  {"campaign": "(not set)", "source": "google", ...  1472865386            1
# 3  {"campaign": "(not set)", "source": "google", ...  1472881213            1
# 4  {"campaign": "(not set)", "source": "google", ...  1472822600            2
#
#    visitStartTime
# 0      1472830385
# 1      1472880147
# 2      1472865386
# 3      1472881213
# 4      1472822600

# %%
DataFrames[files[1]].columns
# Out:
# Index(['channelGrouping', 'date', 'device', 'fullVisitorId', 'geoNetwork',
#        'sessionId', 'socialEngagementType', 'totals', 'trafficSource',
#        'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %% [markdown]
# Now we need to extract some information out of certain columns

# %%
import json
from pandas.io.json import json_normalize

# %%
def load_df(csv_path='./data/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df
# Out:
# ['test.csv', 'train.csv']

# %%
train=load_df()
# Out:
# Loaded train.csv. Shape: (903653, 55)

# %%
train.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime device.browser             device.browserSize  \
# 0            1      1472830385         Chrome  not available in demo dataset
# 1            1      1472880147        Firefox  not available in demo dataset
# 2            1      1472865386         Chrome  not available in demo dataset
# 3            1      1472881213     UC Browser  not available in demo dataset
# 4            2      1472822600         Chrome  not available in demo dataset
#
#           ...          trafficSource.adwordsClickInfo.isVideoAd  \
# 0         ...                                               NaN
# 1         ...                                               NaN
# 2         ...                                               NaN
# 3         ...                                               NaN
# 4         ...                                               NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    trafficSource.campaign trafficSource.campaignCode  \
# 0               (not set)                        NaN
# 1               (not set)                        NaN
# 2               (not set)                        NaN
# 3               (not set)                        NaN
# 4               (not set)                        NaN
#
#   trafficSource.isTrueDirect trafficSource.keyword trafficSource.medium  \
# 0                        NaN        (not provided)              organic
# 1                        NaN        (not provided)              organic
# 2                        NaN        (not provided)              organic
# 3                        NaN       google + online              organic
# 4                       True        (not provided)              organic
#
#   trafficSource.referralPath trafficSource.source
# 0                        NaN               google
# 1                        NaN               google
# 2                        NaN               google
# 3                        NaN               google
# 4                        NaN               google
#
# [5 rows x 55 columns]

# %%
test=load_df(csv_path='./data/test.csv')
# Out:
# Loaded test.csv. Shape: (804684, 53)

# %%
test.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  6167871330617112363
# 1  Organic Search  20171016  0643697640977915618
# 2  Organic Search  20171016  6059383810968229466
# 3  Organic Search  20171016  2376720078563423631
# 4  Organic Search  20171016  2314544520795440038
#
#                         sessionId  socialEngagementType     visitId  \
# 0  6167871330617112363_1508151024  Not Socially Engaged  1508151024
# 1  0643697640977915618_1508175522  Not Socially Engaged  1508175522
# 2  6059383810968229466_1508143220  Not Socially Engaged  1508143220
# 3  2376720078563423631_1508193530  Not Socially Engaged  1508193530
# 4  2314544520795440038_1508217442  Not Socially Engaged  1508217442
#
#    visitNumber  visitStartTime device.browser             device.browserSize  \
# 0            2      1508151024         Chrome  not available in demo dataset
# 1            1      1508175522         Chrome  not available in demo dataset
# 2            1      1508143220         Chrome  not available in demo dataset
# 3            1      1508193530         Safari  not available in demo dataset
# 4            1      1508217442         Safari  not available in demo dataset
#
#           ...          trafficSource.adwordsClickInfo.gclId  \
# 0         ...                                           NaN
# 1         ...                                           NaN
# 2         ...                                           NaN
# 3         ...                                           NaN
# 4         ...                                           NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page  trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                       True        (not provided)
# 1              (not set)                        NaN        (not provided)
# 2              (not set)                        NaN        (not provided)
# 3              (not set)                        NaN        (not provided)
# 4              (not set)                        NaN        (not provided)
#
#   trafficSource.medium trafficSource.referralPath trafficSource.source
# 0              organic                        NaN               google
# 1              organic                        NaN               google
# 2              organic                        NaN               google
# 3              organic                        NaN               google
# 4              organic                        NaN               google
#
# [5 rows x 53 columns]

# %%
train_small=train[0:10000]

# %%
train_small[train_small['trafficSource.adwordsClickInfo.page'].isnull()]
# Out:
#      channelGrouping      date        fullVisitorId  \
# 0     Organic Search  20160902  1131660440785968503
# 1     Organic Search  20160902   377306020877927890
# 2     Organic Search  20160902  3895546263509774583
# 3     Organic Search  20160902  4763447161404445595
# 4     Organic Search  20160902    27294437909732085
# 5     Organic Search  20160902  2938943183656635653
# 6     Organic Search  20160902  1905672039242460897
# 7     Organic Search  20160902   537222803633850821
# 8     Organic Search  20160902  4445454811831400414
# 9     Organic Search  20160902  9499785259412240342
# 10    Organic Search  20160902  0523069750702990437
# 11    Organic Search  20160902   982320996976275749
# 12    Organic Search  20160902   357659889600827884
# 13    Organic Search  20160902  1438082600262726746
# 14    Organic Search  20160902  3531015320757710684
# 15    Organic Search  20160902  9638207207743070032
# 16    Organic Search  20160902  9876750586615598787
# 10              1      1472834967             Chrome
# 11              1      1472849434             Safari
# 12              1      1472839882             Safari
# 13              1      1472803483             Safari
# 14              1      1472868337             Chrome
# 15              1      1472824614             Chrome
# 16              1      1472801099             Chrome
# 17              1      1472826820  Internet Explorer
# 18              1      1472804607             Chrome
# 19              1      1472856874             Chrome
# 20              1      1472826420             Chrome
# 21              1      1472863754             Chrome
# 22              1      1472872530             Safari
# 23              1      1472808484             Chrome
# 24              1      1472806593             Chrome
# 25              1      1472816048  Internet Explorer
# 26              1      1472808002            Firefox
# 27              1      1472885255             Safari
# 28              1      1472828340             Chrome
# 29              1      1472839261             Chrome
# ...           ...             ...                ...
# 9969            1      1486178351             Chrome
# 9971            1      1486175145             Chrome
# 9972            1      1486158472             Chrome
# 9973            1      1486162157             Chrome
# 9974            1      1486149212             Chrome
# 9975            1      1486140635             Safari
# 9976           16      1486148703             Safari
# 9977            1      1486155450             Chrome
# 9978            1      1486167873             Chrome
# 9979            1      1486155490             Chrome
# 9980            1      1486177822             Safari
# 9981            1      1486139607             Chrome
# 9982            1      1486111448             Chrome
# 9983            1      1486173828             Chrome
# 9984            1      1486137164             Chrome
# 9985            1      1486123099             Chrome
# 9986            1      1486157405             Safari
# 9987            1      1486148530             Chrome
# 9988            3      1486145573             Chrome
# 9989            2      1486152714             Chrome
# 9990            1      1486124732             Chrome
# 9991            1      1486143694             Chrome
# 9992            1      1486143895             Safari
# 9993            2      1486134885             Chrome
# 9994            1      1486169540             Chrome
# 9995            1      1486141009             Chrome
# 9996            1      1486155265             Chrome
# 9997            1      1486147069             Chrome
# 9998            1      1486166553             Chrome
# 9999            2      1486145666             Chrome
#
#                  device.browserSize          ...           \
# 0     not available in demo dataset          ...
# 1     not available in demo dataset          ...
# 2     not available in demo dataset          ...
# 3     not available in demo dataset          ...
# 4     not available in demo dataset          ...
# 5     not available in demo dataset          ...
# 6     not available in demo dataset          ...
# 7     not available in demo dataset          ...
# 8     not available in demo dataset          ...
# 9     not available in demo dataset          ...
# 10    not available in demo dataset          ...
# 11    not available in demo dataset          ...
# 12    not available in demo dataset          ...
# 13    not available in demo dataset          ...
# 14    not available in demo dataset          ...
# 15    not available in demo dataset          ...
# 16    not available in demo dataset          ...
# 17    not available in demo dataset          ...
# 18    not available in demo dataset          ...
# 19    not available in demo dataset          ...
# 20    not available in demo dataset          ...
# 21    not available in demo dataset          ...
# 22    not available in demo dataset          ...
# 23    not available in demo dataset          ...
# 24    not available in demo dataset          ...
# 25    not available in demo dataset          ...
# 26    not available in demo dataset          ...
# 27    not available in demo dataset          ...
# 28    not available in demo dataset          ...
# 29    not available in demo dataset          ...
# ...                             ...          ...
# 9969  not available in demo dataset          ...
# 9971  not available in demo dataset          ...
# 9972  not available in demo dataset          ...
# 9973  not available in demo dataset          ...
# 9974  not available in demo dataset          ...
# 9975  not available in demo dataset          ...
# 9976  not available in demo dataset          ...
# 9977  not available in demo dataset          ...
# 9978  not available in demo dataset          ...
# 9979  not available in demo dataset          ...
# 9980  not available in demo dataset          ...
# 9981  not available in demo dataset          ...
# 9982  not available in demo dataset          ...
# 9983  not available in demo dataset          ...
# 9984  not available in demo dataset          ...
# 9985  not available in demo dataset          ...
# 9986  not available in demo dataset          ...
# 9987  not available in demo dataset          ...
# 9988  not available in demo dataset          ...
# 9989  not available in demo dataset          ...
# 9990  not available in demo dataset          ...
# 9991  not available in demo dataset          ...
# 9992  not available in demo dataset          ...
# 9993  not available in demo dataset          ...
# 9994  not available in demo dataset          ...
# 9995  not available in demo dataset          ...
# 9996  not available in demo dataset          ...
# 9997  not available in demo dataset          ...
# 9998  not available in demo dataset          ...
# 9999  not available in demo dataset          ...
#
#      trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ...                                       ...
# 9969                                      NaN
# 9971                                      NaN
# 9972                                      NaN
# 9973                                      NaN
# 9974                                      NaN
# 9975                                      NaN
# 9976                                      NaN
# 9977                                      NaN
# 9978                                      NaN
# 9979                                      NaN
# 9980                                      NaN
# 9981                                      NaN
# 9982                                      NaN
# 9983                                      NaN
# 9984                                      NaN
# 9985                                      NaN
# 9986                                      NaN
# 9987                                      NaN
# 9988                                      NaN
# 9989                                      NaN
# 9990                                      NaN
# 9991                                      NaN
# 9992                                      NaN
# 9993                                      NaN
# 9994                                      NaN
# 9995                                      NaN
# 9996                                      NaN
# 9997                                      NaN
# 9998                                      NaN
# 9999                                      NaN
#
#      trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                    NaN                                 NaN
# 8                                    NaN                                 NaN
# 9                                    NaN                                 NaN
# 10                                   NaN                                 NaN
# 11                                   NaN                                 NaN
# 12                                   NaN                                 NaN
# 13                                   NaN                                 NaN
# 14                                   NaN                                 NaN
# 15                                   NaN                                 NaN
# 16                                   NaN                                 NaN
# 17                                   NaN                                 NaN
# 18                                   NaN                                 NaN
# 19                                   NaN                                 NaN
# 20                                   NaN                                 NaN
# 21                                   NaN                                 NaN
# 22                                   NaN                                 NaN
# 23                                   NaN                                 NaN
# 24                                   NaN                                 NaN
# 25                                   NaN                                 NaN
# 26                                   NaN                                 NaN
# 27                                   NaN                                 NaN
# 28                                   NaN                                 NaN
# 29                                   NaN                                 NaN
# ...                                  ...                                 ...
# 9969                                 NaN                                 NaN
# 9971                                 NaN                                 NaN
# 9972                                 NaN                                 NaN
# 9973                                 NaN                                 NaN
# 9974                                 NaN                                 NaN
# 9975                                 NaN                                 NaN
# 9976                                 NaN                                 NaN
# 9977                                 NaN                                 NaN
# 9978                                 NaN                                 NaN
# 9979                                 NaN                                 NaN
# 9980                                 NaN                                 NaN
# 9981                                 NaN                                 NaN
# 9982                                 NaN                                 NaN
# 9983                                 NaN                                 NaN
# 9984                                 NaN                                 NaN
# 9985                                 NaN                                 NaN
# 9986                                 NaN                                 NaN
# 9987                                 NaN                                 NaN
# 9988                                 NaN                                 NaN
# 9989                                 NaN                                 NaN
# 9990                                 NaN                                 NaN
# 9991                                 NaN                                 NaN
# 9992                                 NaN                                 NaN
# 9993                                 NaN                                 NaN
# 9994                                 NaN                                 NaN
# 9995                                 NaN                                 NaN
# 9996                                 NaN                                 NaN
# 9997                                 NaN                                 NaN
# 9998                                 NaN                                 NaN
# 9999                                 NaN                                 NaN
#
#       trafficSource.campaign trafficSource.campaignCode  \
# 0                  (not set)                        NaN
# 1                  (not set)                        NaN
# 2                  (not set)                        NaN
# 3                  (not set)                        NaN
# 4                  (not set)                        NaN
# 5                  (not set)                        NaN
# 6                  (not set)                        NaN
# 7                  (not set)                        NaN
# 8                  (not set)                        NaN
# 9                  (not set)                        NaN
# 10                 (not set)                        NaN
# 11                 (not set)                        NaN
# 12                 (not set)                        NaN
# 13                 (not set)                        NaN
# 14                 (not set)                        NaN
# 15                 (not set)                        NaN
# 16                 (not set)                        NaN
# 17                 (not set)                        NaN
# 18                 (not set)                        NaN
# 19                 (not set)                        NaN
# 20                 (not set)                        NaN
# 21                 (not set)                        NaN
# 22                 (not set)                        NaN
# 23                 (not set)                        NaN
# 24                 (not set)                        NaN
# 25                 (not set)                        NaN
# 26                 (not set)                        NaN
# 27                 (not set)                        NaN
# 28                 (not set)                        NaN
# 29                 (not set)                        NaN
# ...                      ...                        ...
# 9969               (not set)                        NaN
# 9971               (not set)                        NaN
# 9972               (not set)                        NaN
# 9973               (not set)                        NaN
# 9974               (not set)                        NaN
# 9975               (not set)                        NaN
# 9976               (not set)                        NaN
# 9977               (not set)                        NaN
# 9978               (not set)                        NaN
# 9979               (not set)                        NaN
# 9980               (not set)                        NaN
# 9981               (not set)                        NaN
# 9982        Data Share Promo                        NaN
# 9983               (not set)                        NaN
# 9984               (not set)                        NaN
# 9985               (not set)                        NaN
# 9986               (not set)                        NaN
# 9987               (not set)                        NaN
# 9988               (not set)                        NaN
# 9989               (not set)                        NaN
# 9990               (not set)                        NaN
# 9991               (not set)                        NaN
# 9992               (not set)                        NaN
# 9993               (not set)                        NaN
# 9994               (not set)                        NaN
# 9995               (not set)                        NaN
# 9996               (not set)                        NaN
# 9997               (not set)                        NaN
# 9998               (not set)                        NaN
# 9999               (not set)                        NaN
#
#      trafficSource.isTrueDirect trafficSource.keyword trafficSource.medium  \
# 0                           NaN        (not provided)              organic
# 1                           NaN        (not provided)              organic
# 2                           NaN        (not provided)              organic
# 3                           NaN       google + online              organic
# 4                          True        (not provided)              organic
# 5                           NaN        (not provided)              organic
# 6                           NaN        (not provided)              organic
# 7                           NaN        (not provided)              organic
# 8                           NaN        (not provided)              organic
# 9                           NaN        (not provided)              organic
# 10                          NaN        (not provided)              organic
# 11                          NaN        (not provided)              organic
# 12                          NaN        (not provided)              organic
# 13                          NaN        (not provided)              organic
# 14                          NaN        (not provided)              organic
# 15                          NaN                   NaN              organic
# 16                          NaN        (not provided)              organic
# 17                          NaN        (not provided)              organic
# 18                          NaN        (not provided)              organic
# 19                          NaN        (not provided)              organic
# 20                          NaN        (not provided)              organic
# 21                          NaN                   NaN              organic
# 22                          NaN        (not provided)              organic
# 23                          NaN        (not provided)              organic
# 24                          NaN        (not provided)              organic
# 25                          NaN        (not provided)              organic
# 26                          NaN        (not provided)              organic
# 27                          NaN        (not provided)              organic
# 28                          NaN                   NaN             referral
# 29                          NaN        (not provided)              organic
# ...                         ...                   ...                  ...
# 9969                        NaN        (not provided)              organic
# 9971                       True                   NaN               (none)
# 9972                        NaN        (not provided)              organic
# 9973                        NaN        (not provided)              organic
# 9974                        NaN        (not provided)              organic
# 9975                        NaN        (not provided)              organic
# 9976                       True        (not provided)              organic
# 9977                        NaN        (not provided)              organic
# 9978                        NaN        (not provided)              organic
# 9979                        NaN        (not provided)              organic
# 9980                        NaN        (not provided)              organic
# 9981                       True                   NaN               (none)
# 9982                        NaN                   NaN            affiliate
# 9983                        NaN                   NaN             referral
# 9984                        NaN                   NaN             referral
# 9985                       True                   NaN               (none)
# 9986                       True                   NaN               (none)
# 9987                       True                   NaN               (none)
# 9988                        NaN                   NaN                  cpm
# 9989                       True                   NaN             referral
# 9990                        NaN                   NaN             referral
# 9991                        NaN                   NaN             referral
# 9992                        NaN        (not provided)              organic
# 9993                       True                   NaN             referral
# 9994                        NaN                   NaN             referral
# 9995                        NaN        (not provided)              organic
# 9996                        NaN        (not provided)              organic
# 9997                        NaN        (not provided)              organic
# 9998                        NaN                   NaN             referral
# 9999                       True        (not provided)              organic
#
#             trafficSource.referralPath  trafficSource.source
# 0                                  NaN                google
# 1                                  NaN                google
# 2                                  NaN                google
# 3                                  NaN                google
# 4                                  NaN                google
# 5                                  NaN                google
# 6                                  NaN                google
# 7                                  NaN                google
# 8                                  NaN                google
# 9                                  NaN                google
# 10                                 NaN                google
# 11                                 NaN                google
# 12                                 NaN                google
# 13                                 NaN                google
# 14                                 NaN                google
# 15                                 NaN                 baidu
# 16                                 NaN                google
# 17                                 NaN                google
# 18                                 NaN                google
# 19                                 NaN                google
# 20                                 NaN                google
# 21                                 NaN                 baidu
# 22                                 NaN                google
# 23                                 NaN                google
# 24                                 NaN                google
# 25                                 NaN                google
# 26                                 NaN                google
# 27                                 NaN                google
# 28                                   /    googleweblight.com
# 29                                 NaN                google
# ...                                ...                   ...
# 9969                               NaN                google
# 9971                               NaN              (direct)
# 9972                               NaN                google
# 9973                               NaN                google
# 9974                               NaN                google
# 9975                               NaN                google
# 9976                               NaN                google
# 9977                               NaN                google
# 9978                               NaN                google
# 9979                               NaN                google
# 9980                               NaN                google
# 9981                               NaN              (direct)
# 9982                               NaN              Partners
# 9983                                 /   mall.googleplex.com
# 9984                                 /   mall.googleplex.com
# 9985                               NaN              (direct)
# 9986                               NaN              (direct)
# 9987                               NaN              (direct)
# 9988                               NaN                   dfa
# 9989                                 /   mall.googleplex.com
# 9990  /permissions/using-the-logo.html          google.co.uk
# 9991                                 /   mall.googleplex.com
# 9992                               NaN                google
# 9993                                 /   mall.googleplex.com
# 9994                                 /   mall.googleplex.com
# 9995                               NaN                google
# 9996                               NaN                google
# 9997                               NaN                google
# 9998                   /analytics/web/  analytics.google.com
# 9999                               NaN                google
#
# [9750 rows x 55 columns]
